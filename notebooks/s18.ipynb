# %%
a = [1, 2, 3]
b = (4, 5)
a.append(4)
a.extend(b)
a.pop()
a + [6, 7]
print(a)
# Out:
# [1, 2, 3, 4, 4]

# %%
nums = [1, 2, 2, 3, 3, 3, 3,3,3,3]
# set(nums)
print(len(set(nums)))
# Out:
# 3

# %%
freq = {}

for num in nums:
    # if num not in freq:
    #     freq[num] = 1
    # else:
    #     freq[num] += 1
    freq[num] = freq.get(num, 0) + 1

print(freq)
# Out:
# {1: 1, 2: 2, 3: 7}

# %%
books = ['Python Crash Course', 'Fluent Python', 'Automate the boring stuff with Python']

# %%
id_list = ['0000001', '000002', '0000001']

id_set = {'0000001', '0000002'}
id_set.add('0000001')

# %%
'0000001' in id_set

'0000001' in id_list  # huge speed difference
# Out:
# {'0000001', '0000002'}

# %%
fruits = {'apple': 2.00, 'orange': 1.49}

# %%
months = ('Jan', 'Feb', 'Mar') # a tuple
month_list = ['Jan', 'Feb', 'Mar'] # a list
months[1]
# Out:
# 'Feb'

# %%
import sys

print(sys.getsizeof(months), sys.getsizeof(month_list))
# Out:
# 64 88

# %%
phone_book = {
    "Nicole": {
        "home": "1234",
        "mobile": "001",
    },
}

# %%
phone_book = [
    {
        "id": 1,
        "name": "Nicole",
        "phones": {
            "home": "1234",
            "mobile": "001",
        },
    },
    {
        "id": 2,
        "name": "Nicole",
    },
]

# %%
"""
deltas     # 1d1e1l1t
retainers
desalt
ternaries
...
"""

# %%
{
    "adelst": [
        "deltas",
        "desalt",
    ],
    "aeeinrrst": [
        "retainers",
        "ternaries",
    ],
}

# %%
data = {
  "Data": {
    "BTC-USD": {
      "TYPE": "953",
      "MARKET": "coinbase",
      "INSTRUMENT": "BTC-USD",
      "MAPPED_INSTRUMENT": "BTC-USD",
      "BASE": "BTC",
      "QUOTE": "USD",
      "BASE_ID": 1,
      "QUOTE_ID": 5,
      "TRANSFORM_FUNCTION": "",
      "CCSEQ": 892949583,
      "PRICE": 110635.06,
      "PRICE_FLAG": "UP",
      "PRICE_LAST_UPDATE_TS": 1761767314,
      "PRICE_LAST_UPDATE_TS_NS": 487000000,
      "LAST_TRADE_QUANTITY": 0.00001,
      "LAST_TRADE_QUOTE_QUANTITY": 1.1063506,
      "LAST_TRADE_ID": "893026505",
      "LAST_TRADE_CCSEQ": 893010129,
      "LAST_TRADE_SIDE": "BUY",
      "LAST_PROCESSED_TRADE_TS": 1761767314,
      "LAST_PROCESSED_TRADE_TS_NS": 487000000,
      "LAST_PROCESSED_TRADE_PRICE": 110635.06,
      "LAST_PROCESSED_TRADE_QUANTITY": 0.00001,
      "LAST_PROCESSED_TRADE_QUOTE_QUANTITY": 1.1063506,
      "LAST_PROCESSED_TRADE_SIDE": "BUY",
      "LAST_PROCESSED_TRADE_CCSEQ": 893010129,
      "BEST_BID": 110640.34,
      "BEST_BID_QUANTITY": 0.30286314,
      "BEST_BID_QUOTE_QUANTITY": 33508.8807830676,
      "BEST_BID_LAST_UPDATE_TS": 1761767314,
      "BEST_BID_LAST_UPDATE_TS_NS": 584150000,
      "BEST_BID_POSITION_IN_BOOK_UPDATE_TS": 1761767314,
      "BEST_BID_POSITION_IN_BOOK_UPDATE_TS_NS": 584150000,
      "BEST_ASK": 110640.35,
      "BEST_ASK_QUANTITY": 0.00001,
      "BEST_ASK_QUOTE_QUANTITY": 1.1064035,
      "BEST_ASK_LAST_UPDATE_TS": 1761767314,
      "BEST_ASK_LAST_UPDATE_TS_NS": 487307000,
      "BEST_ASK_POSITION_IN_BOOK_UPDATE_TS": 1761767308,
      "BEST_ASK_POSITION_IN_BOOK_UPDATE_TS_NS": 917463000,
      "CURRENT_HOUR_VOLUME": 473.87170261,
      "CURRENT_HOUR_VOLUME_BUY": 216.79012359,
      "CURRENT_HOUR_VOLUME_SELL": 257.08157902,
      "CURRENT_HOUR_VOLUME_UNKNOWN": 0,
      "CURRENT_HOUR_QUOTE_VOLUME": 52542409.9393112,
      "CURRENT_HOUR_QUOTE_VOLUME_BUY": 24046128.6973434,
      "CURRENT_HOUR_QUOTE_VOLUME_SELL": 28496281.2419694,
      "CURRENT_HOUR_QUOTE_VOLUME_UNKNOWN": 0,
      "CURRENT_HOUR_OPEN": 110807.88,
      "CURRENT_HOUR_HIGH": 111460.29,
      "CURRENT_HOUR_LOW": 110164.25,
      "CURRENT_HOUR_TOTAL_TRADES": 26012,
      "CURRENT_HOUR_TOTAL_TRADES_BUY": 12710,
      "CURRENT_HOUR_TOTAL_TRADES_SELL": 13302,
      "CURRENT_HOUR_TOTAL_TRADES_UNKNOWN": 0,
      "CURRENT_HOUR_CHANGE": -172.82,
      "CURRENT_HOUR_CHANGE_PERCENTAGE": -0.155963637243127,
      "CURRENT_DAY_VOLUME": 5121.6414562,
      "CURRENT_DAY_VOLUME_BUY": 2532.87558819,
      "CURRENT_DAY_VOLUME_SELL": 2588.76586801,
      "CURRENT_DAY_VOLUME_UNKNOWN": 0,
      "CURRENT_DAY_QUOTE_VOLUME": 573181382.126232,
      "CURRENT_DAY_QUOTE_VOLUME_BUY": 283784424.049002,
      "CURRENT_DAY_QUOTE_VOLUME_SELL": 289396958.077033,
      "CURRENT_DAY_QUOTE_VOLUME_UNKNOWN": 0,
      "CURRENT_DAY_OPEN": 112906.75,
      "CURRENT_DAY_HIGH": 113690.17,
      "CURRENT_DAY_LOW": 109000,
      "CURRENT_DAY_TOTAL_TRADES": 308426,
      "CURRENT_DAY_TOTAL_TRADES_BUY": 170514,
      "CURRENT_DAY_TOTAL_TRADES_SELL": 137912,
      "CURRENT_DAY_TOTAL_TRADES_UNKNOWN": 0,
      "CURRENT_DAY_CHANGE": -2271.69,
      "CURRENT_DAY_CHANGE_PERCENTAGE": -2.0120054824003,
      "CURRENT_WEEK_VOLUME": 15962.6132373,
      "CURRENT_WEEK_VOLUME_BUY": 8325.69329146,
      "CURRENT_WEEK_VOLUME_SELL": 7636.91994584,
      "CURRENT_WEEK_VOLUME_UNKNOWN": 0,
      "CURRENT_WEEK_QUOTE_VOLUME": 1816354695.53899,
      "CURRENT_WEEK_QUOTE_VOLUME_BUY": 948183346.009826,
      "CURRENT_WEEK_QUOTE_VOLUME_SELL": 868171349.528886,
      "CURRENT_WEEK_QUOTE_VOLUME_UNKNOWN": 0,
      "CURRENT_WEEK_OPEN": 114548.09,
      "CURRENT_WEEK_HIGH": 116410.06,
      "CURRENT_WEEK_LOW": 109000,
      "CURRENT_WEEK_TOTAL_TRADES": 968813,
      "CURRENT_WEEK_TOTAL_TRADES_BUY": 541933,
      "CURRENT_WEEK_TOTAL_TRADES_SELL": 426880,
      "CURRENT_WEEK_TOTAL_TRADES_UNKNOWN": 0,
      "CURRENT_WEEK_CHANGE": -3913.03,
      "CURRENT_WEEK_CHANGE_PERCENTAGE": -3.41605870512551,
      "CURRENT_MONTH_VOLUME": 239848.52973963,
      "CURRENT_MONTH_VOLUME_BUY": 123796.3213795,
      "CURRENT_MONTH_VOLUME_SELL": 116052.20836013,
      "CURRENT_MONTH_VOLUME_UNKNOWN": 0,
      "CURRENT_MONTH_QUOTE_VOLUME": 27442171394.7089,
      "CURRENT_MONTH_QUOTE_VOLUME_BUY": 14174573590.9539,
      "CURRENT_MONTH_QUOTE_VOLUME_SELL": 13267597803.7451,
      "CURRENT_MONTH_QUOTE_VOLUME_UNKNOWN": 0,
      "CURRENT_MONTH_OPEN": 114067.71,
      "CURRENT_MONTH_HIGH": 126296,
      "CURRENT_MONTH_LOW": 103516.75,
      "CURRENT_MONTH_TOTAL_TRADES": 13252529,
      "CURRENT_MONTH_TOTAL_TRADES_BUY": 7379833,
      "CURRENT_MONTH_TOTAL_TRADES_SELL": 5872696,
      "CURRENT_MONTH_TOTAL_TRADES_UNKNOWN": 0,
      "CURRENT_MONTH_CHANGE": -3432.65,
      "CURRENT_MONTH_CHANGE_PERCENTAGE": -3.00930911999548,
      "CURRENT_YEAR_VOLUME": 2456790.68357563,
      "CURRENT_YEAR_VOLUME_BUY": 1225238.39413875,
      "CURRENT_YEAR_VOLUME_SELL": 1231552.28943688,
      "CURRENT_YEAR_VOLUME_UNKNOWN": 0,
      "CURRENT_YEAR_QUOTE_VOLUME": 248137543151.253,
      "CURRENT_YEAR_QUOTE_VOLUME_BUY": 123689918747.163,
      "CURRENT_YEAR_QUOTE_VOLUME_SELL": 124447624404.171,
      "CURRENT_YEAR_QUOTE_VOLUME_UNKNOWN": 0,
      "CURRENT_YEAR_OPEN": 93354.22,
      "CURRENT_YEAR_HIGH": 126296,
      "CURRENT_YEAR_LOW": 74420.69,
      "CURRENT_YEAR_TOTAL_TRADES": 141525365,
      "CURRENT_YEAR_TOTAL_TRADES_BUY": 80791380,
      "CURRENT_YEAR_TOTAL_TRADES_SELL": 60733985,
      "CURRENT_YEAR_TOTAL_TRADES_UNKNOWN": 0,
      "CURRENT_YEAR_CHANGE": 17280.84,
      "CURRENT_YEAR_CHANGE_PERCENTAGE": 18.5110432072594,
      "MOVING_24_HOUR_VOLUME": 6236.6059009,
      "MOVING_24_HOUR_VOLUME_BUY": 3104.05006974,
      "MOVING_24_HOUR_VOLUME_SELL": 3132.55583116,
      "MOVING_24_HOUR_VOLUME_UNKNOWN": 0,
      "MOVING_24_HOUR_QUOTE_VOLUME": 699023615.253291,
      "MOVING_24_HOUR_QUOTE_VOLUME_BUY": 348234213.373699,
      "MOVING_24_HOUR_QUOTE_VOLUME_SELL": 350789401.879633,
      "MOVING_24_HOUR_QUOTE_VOLUME_UNKNOWN": 0,
      "MOVING_24_HOUR_OPEN": 113687.51,
      "MOVING_24_HOUR_HIGH": 113707.09,
      "MOVING_24_HOUR_LOW": 109000,
      "MOVING_24_HOUR_TOTAL_TRADES": 384948,
      "MOVING_24_HOUR_TOTAL_TRADES_BUY": 213957,
      "MOVING_24_HOUR_TOTAL_TRADES_SELL": 170991,
      "MOVING_24_HOUR_TOTAL_TRADES_UNKNOWN": 0,
      "MOVING_24_HOUR_CHANGE": -3052.45,
      "MOVING_24_HOUR_CHANGE_PERCENTAGE": -2.68494753733282,
      "MOVING_7_DAY_VOLUME": 34049.78155346,
      "MOVING_7_DAY_VOLUME_BUY": 18015.77878936,
      "MOVING_7_DAY_VOLUME_SELL": 16034.0027641,
      "MOVING_7_DAY_VOLUME_UNKNOWN": 0,
      "MOVING_7_DAY_QUOTE_VOLUME": 3823311743.07099,
      "MOVING_7_DAY_QUOTE_VOLUME_BUY": 2023422929.65118,
      "MOVING_7_DAY_QUOTE_VOLUME_SELL": 1799888813.41937,
      "MOVING_7_DAY_QUOTE_VOLUME_UNKNOWN": 0,
      "MOVING_7_DAY_OPEN": 107585.98,
      "MOVING_7_DAY_HIGH": 116410.06,
      "MOVING_7_DAY_LOW": 107511.46,
      "MOVING_7_DAY_TOTAL_TRADES": 2124925,
      "MOVING_7_DAY_TOTAL_TRADES_BUY": 1229449,
      "MOVING_7_DAY_TOTAL_TRADES_SELL": 895476,
      "MOVING_7_DAY_TOTAL_TRADES_UNKNOWN": 0,
      "MOVING_7_DAY_CHANGE": 3049.08,
      "MOVING_7_DAY_CHANGE_PERCENTAGE": 2.83408674624705,
      "MOVING_30_DAY_VOLUME": 244893.10021843,
      "MOVING_30_DAY_VOLUME_BUY": 126113.88092179,
      "MOVING_30_DAY_VOLUME_SELL": 118779.21929664,
      "MOVING_30_DAY_VOLUME_UNKNOWN": 0,
      "MOVING_30_DAY_QUOTE_VOLUME": 28015967590.1964,
      "MOVING_30_DAY_QUOTE_VOLUME_BUY": 14438209422.1987,
      "MOVING_30_DAY_QUOTE_VOLUME_SELL": 13577758167.9876,
      "MOVING_30_DAY_QUOTE_VOLUME_UNKNOWN": 0,
      "MOVING_30_DAY_OPEN": 114365.07,
      "MOVING_30_DAY_HIGH": 126296,
      "MOVING_30_DAY_LOW": 103516.75,
      "MOVING_30_DAY_TOTAL_TRADES": 13563870,
      "MOVING_30_DAY_TOTAL_TRADES_BUY": 7564327,
      "MOVING_30_DAY_TOTAL_TRADES_SELL": 5999543,
      "MOVING_30_DAY_TOTAL_TRADES_UNKNOWN": 0,
      "MOVING_30_DAY_CHANGE": -3730.01,
      "MOVING_30_DAY_CHANGE_PERCENTAGE": -3.26149409080937,
      "MOVING_90_DAY_VOLUME": 558641.32753871,
      "MOVING_90_DAY_VOLUME_BUY": 279506.47061484,
      "MOVING_90_DAY_VOLUME_SELL": 279134.85692387,
      "MOVING_90_DAY_VOLUME_UNKNOWN": 0,
      "MOVING_90_DAY_QUOTE_VOLUME": 63805181427.6979,
      "MOVING_90_DAY_QUOTE_VOLUME_BUY": 31934230075.1041,
      "MOVING_90_DAY_QUOTE_VOLUME_SELL": 31870951352.5848,
      "MOVING_90_DAY_QUOTE_VOLUME_UNKNOWN": 0,
      "MOVING_90_DAY_OPEN": 115761.13,
      "MOVING_90_DAY_HIGH": 126296,
      "MOVING_90_DAY_LOW": 103516.75,
      "MOVING_90_DAY_TOTAL_TRADES": 36384678,
      "MOVING_90_DAY_TOTAL_TRADES_BUY": 20860062,
      "MOVING_90_DAY_TOTAL_TRADES_SELL": 15524616,
      "MOVING_90_DAY_TOTAL_TRADES_UNKNOWN": 0,
      "MOVING_90_DAY_CHANGE": -5126.07,
      "MOVING_90_DAY_CHANGE_PERCENTAGE": -4.42814440391174,
      "MOVING_180_DAY_VOLUME": 1144608.47864234,
      "MOVING_180_DAY_VOLUME_BUY": 568164.38167688,
      "MOVING_180_DAY_VOLUME_SELL": 576444.09696546,
      "MOVING_180_DAY_VOLUME_UNKNOWN": 0,
      "MOVING_180_DAY_QUOTE_VOLUME": 127757209362.915,
      "MOVING_180_DAY_QUOTE_VOLUME_BUY": 63510401197.6396,
      "MOVING_180_DAY_QUOTE_VOLUME_SELL": 64246808165.2614,
      "MOVING_180_DAY_QUOTE_VOLUME_UNKNOWN": 0,
      "MOVING_180_DAY_OPEN": 96929.81,
      "MOVING_180_DAY_HIGH": 126296,
      "MOVING_180_DAY_LOW": 93363.28,
      "MOVING_180_DAY_TOTAL_TRADES": 73026731,
      "MOVING_180_DAY_TOTAL_TRADES_BUY": 42181541,
      "MOVING_180_DAY_TOTAL_TRADES_SELL": 30845190,
      "MOVING_180_DAY_TOTAL_TRADES_UNKNOWN": 0,
      "MOVING_180_DAY_CHANGE": 13705.25,
      "MOVING_180_DAY_CHANGE_PERCENTAGE": 14.1393550652787,
      "MOVING_365_DAY_VOLUME": 3451530.29133031,
      "MOVING_365_DAY_VOLUME_BUY": 1720511.81230886,
      "MOVING_365_DAY_VOLUME_SELL": 1731018.47902145,
      "MOVING_365_DAY_VOLUME_UNKNOWN": 0,
      "MOVING_365_DAY_QUOTE_VOLUME": 339162023871.729,
      "MOVING_365_DAY_QUOTE_VOLUME_BUY": 168924659519.959,
      "MOVING_365_DAY_QUOTE_VOLUME_SELL": 170237364351.834,
      "MOVING_365_DAY_QUOTE_VOLUME_UNKNOWN": 0,
      "MOVING_365_DAY_OPEN": 72724.35,
      "MOVING_365_DAY_HIGH": 126296,
      "MOVING_365_DAY_LOW": 66783.77,
      "MOVING_365_DAY_TOTAL_TRADES": 185288770,
      "MOVING_365_DAY_TOTAL_TRADES_BUY": 107126780,
      "MOVING_365_DAY_TOTAL_TRADES_SELL": 78161990,
      "MOVING_365_DAY_TOTAL_TRADES_UNKNOWN": 0,
      "MOVING_365_DAY_CHANGE": 37910.71,
      "MOVING_365_DAY_CHANGE_PERCENTAGE": 52.1293211970956,
      "LIFETIME_FIRST_TRADE_TS": 1417412037,
      "LIFETIME_VOLUME": 53771320.0409634,
      "LIFETIME_VOLUME_BUY": 25854558.3904126,
      "LIFETIME_VOLUME_SELL": 27916760.1034026,
      "LIFETIME_VOLUME_UNKNOWN": 1.53,
      "LIFETIME_QUOTE_VOLUME": 1420899780225.33,
      "LIFETIME_QUOTE_VOLUME_BUY": 698176962284.755,
      "LIFETIME_QUOTE_VOLUME_SELL": 722722809757.203,
      "LIFETIME_QUOTE_VOLUME_UNKNOWN": 459,
      "LIFETIME_OPEN": 300,
      "LIFETIME_HIGH": 126296,
      "LIFETIME_HIGH_TS": 1759777092,
      "LIFETIME_LOW": 0.06,
      "LIFETIME_LOW_TS": 1492297346,
      "LIFETIME_TOTAL_TRADES": 892931772,
      "LIFETIME_TOTAL_TRADES_BUY": 435965442,
      "LIFETIME_TOTAL_TRADES_SELL": 456966177,
      "LIFETIME_TOTAL_TRADES_UNKNOWN": 153,
      "LIFETIME_CHANGE": 110335.06,
      "LIFETIME_CHANGE_PERCENTAGE": 36778.3533333333
    },
    "ETH-USD": {
      "TYPE": "953",
      "MARKET": "coinbase",
      "INSTRUMENT": "ETH-USD",
      "MAPPED_INSTRUMENT": "ETH-USD",
      "BASE": "ETH",
      "QUOTE": "USD",
      "BASE_ID": 2,
      "QUOTE_ID": 5,
      "TRANSFORM_FUNCTION": "",
      "CCSEQ": 722113066,
      "PRICE": 3913.96,
      "PRICE_FLAG": "UNCHANGED",
      "PRICE_LAST_UPDATE_TS": 1761767313,
      "PRICE_LAST_UPDATE_TS_NS": 259000000,
      "LAST_TRADE_QUANTITY": 0.40373785,
      "LAST_TRADE_QUOTE_QUANTITY": 1580.213795386,
      "LAST_TRADE_ID": "720448558",
      "LAST_TRADE_CCSEQ": 719169902,
      "LAST_TRADE_SIDE": "SELL",
      "LAST_PROCESSED_TRADE_TS": 1761767313,
      "LAST_PROCESSED_TRADE_TS_NS": 259000000,
      "LAST_PROCESSED_TRADE_PRICE": 3913.96,
      "LAST_PROCESSED_TRADE_QUANTITY": 0.40373785,
      "LAST_PROCESSED_TRADE_QUOTE_QUANTITY": 1580.213795386,
      "LAST_PROCESSED_TRADE_SIDE": "SELL",
      "LAST_PROCESSED_TRADE_CCSEQ": 719169902,
      "BEST_BID": 3914.04,
      "BEST_BID_QUANTITY": 0.0956,
      "BEST_BID_QUOTE_QUANTITY": 374.182224,
      "BEST_BID_LAST_UPDATE_TS": 1761767314,
      "BEST_BID_LAST_UPDATE_TS_NS": 176118000,
      "BEST_BID_POSITION_IN_BOOK_UPDATE_TS": 1761767314,
      "BEST_BID_POSITION_IN_BOOK_UPDATE_TS_NS": 176118000,
      "BEST_ASK": 3914.05,
      "BEST_ASK_QUANTITY": 0.00295999,
      "BEST_ASK_QUOTE_QUANTITY": 11.5855488595,
      "BEST_ASK_LAST_UPDATE_TS": 1761767314,
      "BEST_ASK_LAST_UPDATE_TS_NS": 216491000,
      "BEST_ASK_POSITION_IN_BOOK_UPDATE_TS": 1761767314,
      "BEST_ASK_POSITION_IN_BOOK_UPDATE_TS_NS": 216491000,
      "CURRENT_HOUR_VOLUME": 9649.27405838,
      "CURRENT_HOUR_VOLUME_BUY": 4368.21333633,
      "CURRENT_HOUR_VOLUME_SELL": 5281.06072205,
      "CURRENT_HOUR_VOLUME_UNKNOWN": 0,
      "CURRENT_HOUR_QUOTE_VOLUME": 37865942.2692289,
      "CURRENT_HOUR_QUOTE_VOLUME_BUY": 17136729.5023402,
      "CURRENT_HOUR_QUOTE_VOLUME_SELL": 20729212.7668852,
      "CURRENT_HOUR_QUOTE_VOLUME_UNKNOWN": 0,
      "CURRENT_HOUR_OPEN": 3918,
      "CURRENT_HOUR_HIGH": 3959.33,
      "CURRENT_HOUR_LOW": 3888.22,
      "CURRENT_HOUR_TOTAL_TRADES": 41213,
      "CURRENT_HOUR_TOTAL_TRADES_BUY": 22272,
      "CURRENT_HOUR_TOTAL_TRADES_SELL": 18941,
      "CURRENT_HOUR_TOTAL_TRADES_UNKNOWN": 0,
      "CURRENT_HOUR_CHANGE": -4.04,
      "CURRENT_HOUR_CHANGE_PERCENTAGE": -0.103113833588566,
      "CURRENT_DAY_VOLUME": 99134.24290795,
      "CURRENT_DAY_VOLUME_BUY": 44156.00695037,
      "CURRENT_DAY_VOLUME_SELL": 54978.23595758,
      "CURRENT_DAY_VOLUME_UNKNOWN": 0,
      "CURRENT_DAY_QUOTE_VOLUME": 393257713.837851,
      "CURRENT_DAY_QUOTE_VOLUME_BUY": 175185299.876496,
      "CURRENT_DAY_QUOTE_VOLUME_SELL": 218072413.960698,
      "CURRENT_DAY_QUOTE_VOLUME_UNKNOWN": 0,
      "CURRENT_DAY_OPEN": 3980.25,
      "CURRENT_DAY_HIGH": 4038.7,
      "CURRENT_DAY_LOW": 3838,
      "CURRENT_DAY_TOTAL_TRADES": 373174,
      "CURRENT_DAY_TOTAL_TRADES_BUY": 189565,
      "CURRENT_DAY_TOTAL_TRADES_SELL": 183609,
      "CURRENT_DAY_TOTAL_TRADES_UNKNOWN": 0,
      "CURRENT_DAY_CHANGE": -66.29,
      "CURRENT_DAY_CHANGE_PERCENTAGE": -1.66547327429182,
      "CURRENT_WEEK_VOLUME": 343657.94280484,
      "CURRENT_WEEK_VOLUME_BUY": 160394.74435094,
      "CURRENT_WEEK_VOLUME_SELL": 183263.1984539,
      "CURRENT_WEEK_VOLUME_UNKNOWN": 0,
      "CURRENT_WEEK_QUOTE_VOLUME": 1403661512.73739,
      "CURRENT_WEEK_QUOTE_VOLUME_BUY": 655402396.078333,
      "CURRENT_WEEK_QUOTE_VOLUME_SELL": 748259116.658393,
      "CURRENT_WEEK_QUOTE_VOLUME_UNKNOWN": 0,
      "CURRENT_WEEK_OPEN": 4158.81,
      "CURRENT_WEEK_HIGH": 4254.23,
      "CURRENT_WEEK_LOW": 3838,
      "CURRENT_WEEK_TOTAL_TRADES": 1190091,
      "CURRENT_WEEK_TOTAL_TRADES_BUY": 626937,
      "CURRENT_WEEK_TOTAL_TRADES_SELL": 563154,
      "CURRENT_WEEK_TOTAL_TRADES_UNKNOWN": 0,
      "CURRENT_WEEK_CHANGE": -244.850000000001,
      "CURRENT_WEEK_CHANGE_PERCENTAGE": -5.88750147277709,
      "CURRENT_MONTH_VOLUME": 4124466.39610123,
      "CURRENT_MONTH_VOLUME_BUY": 1916262.24318016,
      "CURRENT_MONTH_VOLUME_SELL": 2208204.15292107,
      "CURRENT_MONTH_VOLUME_UNKNOWN": 0,
      "CURRENT_MONTH_QUOTE_VOLUME": 17058967029.8402,
      "CURRENT_MONTH_QUOTE_VOLUME_BUY": 7899361315.20859,
      "CURRENT_MONTH_QUOTE_VOLUME_SELL": 9159605714.63088,
      "CURRENT_MONTH_QUOTE_VOLUME_UNKNOWN": 0,
      "CURRENT_MONTH_OPEN": 4145.99,
      "CURRENT_MONTH_HIGH": 4759.16,
      "CURRENT_MONTH_LOW": 3510,
      "CURRENT_MONTH_TOTAL_TRADES": 14637932,
      "CURRENT_MONTH_TOTAL_TRADES_BUY": 7027371,
      "CURRENT_MONTH_TOTAL_TRADES_SELL": 7610561,
      "CURRENT_MONTH_TOTAL_TRADES_UNKNOWN": 0,
      "CURRENT_MONTH_CHANGE": -232.03,
      "CURRENT_MONTH_CHANGE_PERCENTAGE": -5.59649203205989,
      "CURRENT_YEAR_VOLUME": 46145743.9645346,
      "CURRENT_YEAR_VOLUME_BUY": 22422326.4584028,
      "CURRENT_YEAR_VOLUME_SELL": 23723417.5061322,
      "CURRENT_YEAR_VOLUME_UNKNOWN": 0,
      "CURRENT_YEAR_QUOTE_VOLUME": 140003280127.247,
      "CURRENT_YEAR_QUOTE_VOLUME_BUY": 67096574764.5568,
      "CURRENT_YEAR_QUOTE_VOLUME_SELL": 72906705362.656,
      "CURRENT_YEAR_QUOTE_VOLUME_UNKNOWN": 0,
      "CURRENT_YEAR_OPEN": 3330.32,
      "CURRENT_YEAR_HIGH": 4955.9,
      "CURRENT_YEAR_LOW": 1383.26,
      "CURRENT_YEAR_TOTAL_TRADES": 130672574,
      "CURRENT_YEAR_TOTAL_TRADES_BUY": 71985857,
      "CURRENT_YEAR_TOTAL_TRADES_SELL": 58686717,
      "CURRENT_YEAR_TOTAL_TRADES_UNKNOWN": 0,
      "CURRENT_YEAR_CHANGE": 583.64,
      "CURRENT_YEAR_CHANGE_PERCENTAGE": 17.5250426385452,
      "MOVING_24_HOUR_VOLUME": 130875.79586543,
      "MOVING_24_HOUR_VOLUME_BUY": 58388.23521194,
      "MOVING_24_HOUR_VOLUME_SELL": 72487.56065349,
      "MOVING_24_HOUR_VOLUME_UNKNOWN": 0,
      "MOVING_24_HOUR_QUOTE_VOLUME": 519656640.78118,
      "MOVING_24_HOUR_QUOTE_VOLUME_BUY": 231848113.766805,
      "MOVING_24_HOUR_QUOTE_VOLUME_SELL": 287808527.014394,
      "MOVING_24_HOUR_QUOTE_VOLUME_UNKNOWN": 0,
      "MOVING_24_HOUR_OPEN": 4041.23,
      "MOVING_24_HOUR_HIGH": 4043.11,
      "MOVING_24_HOUR_LOW": 3838,
      "MOVING_24_HOUR_TOTAL_TRADES": 475320,
      "MOVING_24_HOUR_TOTAL_TRADES_BUY": 244800,
      "MOVING_24_HOUR_TOTAL_TRADES_SELL": 230520,
      "MOVING_24_HOUR_TOTAL_TRADES_UNKNOWN": 0,
      "MOVING_24_HOUR_CHANGE": -127.27,
      "MOVING_24_HOUR_CHANGE_PERCENTAGE": -3.14928870665614,
      "MOVING_7_DAY_VOLUME": 669396.20207803,
      "MOVING_7_DAY_VOLUME_BUY": 327612.01777942,
      "MOVING_7_DAY_VOLUME_SELL": 341784.18429861,
      "MOVING_7_DAY_VOLUME_UNKNOWN": 0,
      "MOVING_7_DAY_QUOTE_VOLUME": 2685059423.27389,
      "MOVING_7_DAY_QUOTE_VOLUME_BUY": 1313395606.08849,
      "MOVING_7_DAY_QUOTE_VOLUME_SELL": 1371663817.1847,
      "MOVING_7_DAY_QUOTE_VOLUME_UNKNOWN": 0,
      "MOVING_7_DAY_OPEN": 3806.12,
      "MOVING_7_DAY_HIGH": 4254.23,
      "MOVING_7_DAY_LOW": 3796.77,
      "MOVING_7_DAY_TOTAL_TRADES": 2386352,
      "MOVING_7_DAY_TOTAL_TRADES_BUY": 1269062,
      "MOVING_7_DAY_TOTAL_TRADES_SELL": 1117290,
      "MOVING_7_DAY_TOTAL_TRADES_UNKNOWN": 0,
      "MOVING_7_DAY_CHANGE": 107.84,
      "MOVING_7_DAY_CHANGE_PERCENTAGE": 2.83333158176831,
      "MOVING_30_DAY_VOLUME": 4236879.69956579,
      "MOVING_30_DAY_VOLUME_BUY": 1955327.78235071,
      "MOVING_30_DAY_VOLUME_SELL": 2281551.91721508,
      "MOVING_30_DAY_VOLUME_UNKNOWN": 0,
      "MOVING_30_DAY_QUOTE_VOLUME": 17526276680.4921,
      "MOVING_30_DAY_QUOTE_VOLUME_BUY": 8061718192.52322,
      "MOVING_30_DAY_QUOTE_VOLUME_SELL": 9464558487.968,
      "MOVING_30_DAY_QUOTE_VOLUME_UNKNOWN": 0,
      "MOVING_30_DAY_OPEN": 4217.25,
      "MOVING_30_DAY_HIGH": 4759.16,
      "MOVING_30_DAY_LOW": 3510,
      "MOVING_30_DAY_TOTAL_TRADES": 14991860,
      "MOVING_30_DAY_TOTAL_TRADES_BUY": 7201885,
      "MOVING_30_DAY_TOTAL_TRADES_SELL": 7789975,
      "MOVING_30_DAY_TOTAL_TRADES_UNKNOWN": 0,
      "MOVING_30_DAY_CHANGE": -303.29,
      "MOVING_30_DAY_CHANGE_PERCENTAGE": -7.19165332859091,
      "MOVING_90_DAY_VOLUME": 13611609.4717126,
      "MOVING_90_DAY_VOLUME_BUY": 6281329.21882668,
      "MOVING_90_DAY_VOLUME_SELL": 7330280.25288574,
      "MOVING_90_DAY_VOLUME_UNKNOWN": 0,
      "MOVING_90_DAY_QUOTE_VOLUME": 57983680724.5832,
      "MOVING_90_DAY_QUOTE_VOLUME_BUY": 26719721187.2189,
      "MOVING_90_DAY_QUOTE_VOLUME_SELL": 31263959537.3444,
      "MOVING_90_DAY_QUOTE_VOLUME_UNKNOWN": 0,
      "MOVING_90_DAY_OPEN": 3698.07,
      "MOVING_90_DAY_HIGH": 4955.9,
      "MOVING_90_DAY_LOW": 3354.56,
      "MOVING_90_DAY_TOTAL_TRADES": 44199758,
      "MOVING_90_DAY_TOTAL_TRADES_BUY": 23220093,
      "MOVING_90_DAY_TOTAL_TRADES_SELL": 20979665,
      "MOVING_90_DAY_TOTAL_TRADES_UNKNOWN": 0,
      "MOVING_90_DAY_CHANGE": 215.89,
      "MOVING_90_DAY_CHANGE_PERCENTAGE": 5.8379100449694,
      "MOVING_180_DAY_VOLUME": 26574851.5369334,
      "MOVING_180_DAY_VOLUME_BUY": 12514629.3136473,
      "MOVING_180_DAY_VOLUME_SELL": 14060222.2232861,
      "MOVING_180_DAY_VOLUME_UNKNOWN": 0,
      "MOVING_180_DAY_QUOTE_VOLUME": 94037027759.7135,
      "MOVING_180_DAY_QUOTE_VOLUME_BUY": 43913418882.5371,
      "MOVING_180_DAY_QUOTE_VOLUME_SELL": 50123608877.1548,
      "MOVING_180_DAY_QUOTE_VOLUME_UNKNOWN": 0,
      "MOVING_180_DAY_OPEN": 1842.98,
      "MOVING_180_DAY_HIGH": 4955.9,
      "MOVING_180_DAY_LOW": 1751.45,
      "MOVING_180_DAY_TOTAL_TRADES": 80156475,
      "MOVING_180_DAY_TOTAL_TRADES_BUY": 43223219,
      "MOVING_180_DAY_TOTAL_TRADES_SELL": 36933256,
      "MOVING_180_DAY_TOTAL_TRADES_UNKNOWN": 0,
      "MOVING_180_DAY_CHANGE": 2070.98,
      "MOVING_180_DAY_CHANGE_PERCENTAGE": 112.371268272038,
      "MOVING_365_DAY_VOLUME": 55312109.6023415,
      "MOVING_365_DAY_VOLUME_BUY": 26937912.9691249,
      "MOVING_365_DAY_VOLUME_SELL": 28374196.6332163,
      "MOVING_365_DAY_VOLUME_UNKNOWN": 0,
      "MOVING_365_DAY_QUOTE_VOLUME": 171118204085.739,
      "MOVING_365_DAY_QUOTE_VOLUME_BUY": 82396147835.3397,
      "MOVING_365_DAY_QUOTE_VOLUME_SELL": 88722056250.3625,
      "MOVING_365_DAY_QUOTE_VOLUME_UNKNOWN": 0,
      "MOVING_365_DAY_OPEN": 2637.85,
      "MOVING_365_DAY_HIGH": 4955.9,
      "MOVING_365_DAY_LOW": 1383.26,
      "MOVING_365_DAY_TOTAL_TRADES": 159370865,
      "MOVING_365_DAY_TOTAL_TRADES_BUY": 88579172,
      "MOVING_365_DAY_TOTAL_TRADES_SELL": 70791693,
      "MOVING_365_DAY_TOTAL_TRADES_UNKNOWN": 0,
      "MOVING_365_DAY_CHANGE": 1276.11,
      "MOVING_365_DAY_CHANGE_PERCENTAGE": 48.3768978524177,
      "LIFETIME_FIRST_TRADE_TS": 1463531104,
      "LIFETIME_VOLUME": 578545444.856148,
      "LIFETIME_VOLUME_BUY": 281995628.022475,
      "LIFETIME_VOLUME_SELL": 296549816.845482,
      "LIFETIME_VOLUME_UNKNOWN": 0,
      "LIFETIME_QUOTE_VOLUME": 853935439652.826,
      "LIFETIME_QUOTE_VOLUME_BUY": 416534532320.67,
      "LIFETIME_QUOTE_VOLUME_SELL": 437400907244.304,
      "LIFETIME_QUOTE_VOLUME_UNKNOWN": 0,
      "LIFETIME_OPEN": 13,
      "LIFETIME_HIGH": 4955.9,
      "LIFETIME_HIGH_TS": 1756060894,
      "LIFETIME_LOW": 0.1,
      "LIFETIME_LOW_TS": 1498073418,
      "LIFETIME_TOTAL_TRADES": 720406149,
      "LIFETIME_TOTAL_TRADES_BUY": 353364641,
      "LIFETIME_TOTAL_TRADES_SELL": 367041508,
      "LIFETIME_TOTAL_TRADES_UNKNOWN": 0,
      "LIFETIME_CHANGE": 3900.96,
      "LIFETIME_CHANGE_PERCENTAGE": 30007.3846153846
    }
  },
  "Err": {

  }
}

# %%
data['Data']['BTC-USD']['PRICE']
# Out:
# 110635.06
