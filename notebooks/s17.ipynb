# %%
name = 'python programming'
set(name)
# Out:
# {' ', 'a', 'g', 'h', 'i', 'm', 'n', 'o', 'p', 'r', 't', 'y'}

# %%
tuple(name)
# Out:
# ('p',
#  'y',
#  't',
#  'h',
#  'o',
#  'n',
#  ' ',
#  'p',
#  'r',
#  'o',
#  'g',
#  'r',
#  'a',
#  'm',
#  'm',
#  'i',
#  'n',
#  'g')

# %%
def f(a, b):
    return a + b, a * b


result = f(3, 2)
print(result)
print(type(result))
# Out:
# (5, 6)
# <class 'tuple'>

# %%
stocks = [
    {'name': 'TSLA', 'price': 500, 'transactions': ['20251026', '20251027']}, 
    {'name': 'MSFT', 'price': 400}, 
    {'name': 'TSLA'}
]

# %%
names = ['TSLA', 'MSFT', 'TSLA']
set(names)
# Out:
# {'MSFT', 'TSLA'}

# %%
set(stock["name"] for stock in stocks)
# Out:
# {'MSFT', 'TSLA'}

# %%
nums = [1, 2, 2, 2, 3, 4, 5, 5, 6, 6, 6, 6]
another_nums = nums[:] # make a copy of nums
for num in another_nums:
    if num % 2 == 0:
        # print(f'before removing {num}:', nums)
        nums.remove(num)
        # print(f'after removing {num}:', nums)

nums
# Out:
# [1, 3, 5, 5]

# %%
nums = [1, 2, 2, 2, 3, 4, 5, 5, 6, 6, 6, 6]
nums.remove(2)
nums.remove(2)
nums.remove(2)
nums
# Out:
# [1, 3, 4, 5, 5, 6, 6, 6, 6]

# %%
# unpacking


phones = ['123-456-7890', '123-4567890']
for phone in phones:
    area_code, *_ = phone.split('-')
    print(area_code)


file_paths = ['c:\\code\\test.py', 'd:\\projects\\oime3640\\session01\\s01.ipynb']

for path in file_paths:
    *whatever, filename = path.split('\\')
    print(filename)
# Out:
# 123
# 123
# test.py
# s01.ipynb
